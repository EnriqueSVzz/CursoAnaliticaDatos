# %% [markdown]
# # Fundamentos de Python

# %% [markdown]
# ### Autocompletado

# %% [markdown]
# * Pulsnado `tab`, podemos ver todas las opciones habilitadas

# %%
import numpy as np

an_apple = 27
a =an_apple


b = [1, 2, 3]
b.count(1)
# Out:
# 1

# %%
 b = [1, 2, 3]

# %% [markdown]
# ### Introspección

# %% [markdown]
# * Utilizar un signo de interrogación (?) antes o después de una variable mostrará información
#  general sobre el objeto.

# %%
 b?
# Out:
# Type:        list
# String form: [1, 2, 3]
# Length:      3
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
print?
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %%
np.array?
# Out:
# Docstring:
# array(object, dtype=None, *, copy=True, order='K', subok=False, ndmin=0,
#       like=None)
#
# Create an array.
#
# Parameters
# ----------
# object : array_like
#     An array, any object exposing the array interface, an object whose
#     ``__array__`` method returns an array, or any (nested) sequence.
#     If object is a scalar, a 0-dimensional array containing object is
#     returned.
# dtype : data-type, optional
#     The desired data-type for the array. If not given, NumPy will try to use
#     a default ``dtype`` that can represent the values (by applying promotion
#     rules when necessary.)
# copy : bool, optional
#     If true (default), then the object is copied.  Otherwise, a copy will
#     only be made if ``__array__`` returns a copy, if obj is a nested
#     sequence, or if a copy is needed to satisfy any of the other
#     requirements (``dtype``, ``order``, etc.).
# order : {'K', 'A', 'C', 'F'}, optional
# ...

# %% [markdown]
# ### DocString

# %% [markdown]
# *  Esto se denomina introspección de objetos. Si el objeto es una función o un método de instancia, la cadena de documentación o docstring, si se ha definido, también se mostrará.
# *  Una serie de caracteres combinados con el carácter comodín (*) mostrará todos los nombres que coinciden con lacexpresión comodín. Por ejemplo, podríamos obtener una lista de todas las funciones del espacio de nombres de alto nivel de NumPy que contengan load.

# %%
def add_numbers(a, b):
 """
 Add two numbers together
 Returns
 ———
the_sum : type of arguments
 """
 return a + b

add_numbers?
# Out:
# Signature: add_numbers(a, b)
# Docstring:
#  Add two numbers together
#  Returns
#  ———
# the_sum : type of arguments
#
# File:      c:\users\pc\appdata\local\temp\ipykernel_18852\3903238572.py
# Type:      function

# %%
# Nos traerá todos los submodulos que complan con esto.
np.*load*?
# Out:
# np.__loader__
# np.load
# np.loadtxt
